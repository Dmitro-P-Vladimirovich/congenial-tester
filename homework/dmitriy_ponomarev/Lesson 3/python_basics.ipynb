# %% [markdown]
# # Python
#
# ## Идентификаторы

# %%
print(42)
print(42.5)
print('text')
print(True)
print(False)
# Out:
# 42
# 42.5
# text
# True
# False

# %%
a = 42

print(2 + a)
# Out:
# 44

# %%
c = '666666'
d = '666666'

print (c is d)
# Out:
# True

# %%
e = 5
print(e % 2)
# Out:
# 1
