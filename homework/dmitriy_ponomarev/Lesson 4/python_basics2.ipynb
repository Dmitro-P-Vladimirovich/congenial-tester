# %%
a = 1

a += 1
# a = a + 1

print(a)
# Out:
# 2

# %%
print('text' + 'text')
text = 'text'
text += ' new'
# text = text + 'new'
print(text)
symbol = '='
symbol *= 30
print(symbol) 
print('Copyright')   
print(symbol)

# %%
text = 'I love Python!'
print('love' in text)
print('Love' in text)
# Out:
# True
# False

# %%
b = 2
print(id(b))
c = 2
print(id(c))
d = 257
print(id(d))
e = 257
print(id(e))
print(b is c)
print(d is not e)
# Out:
# 140718664141272
# 140718664141272
# 2561360766736
# 2561360768272
# True
# True

# %%
input('What is your name?')
a = 1

# %%
user_name = input('What is your name?')
print('Hello', user_name, '!')

# %%
user_input = int(input('Enter a number'))
print(type(user_input))

print(2 + user_input)
# Out:
# <class 'int'>
# 4

# %%
a = '1'
print(type(a))
a = int(a)
print(type(a))
a = str(a)
print(type(a))
b = 'True'
print(type(b))
b = bool(b)
print(type(b))
a = float(a)
print(type(a))

# %%
my_list = [1, 3, None, 2.22, True, 'text']
print(my_list)
print(my_list[2])
print(my_list[0])
print(my_list[-1])
print(my_list[-3])

my_list[2] = 42
print(my_list)

# %%
my_list = []
my_list = list()
my_list.append(228)
my_list.append('text')
print(my_list)
print(len(my_list))
print(my_list.index('text'))
poped = my_list.pop(1)
print(my_list)
print(poped)

print('text' in my_list)

# %%
my_tuple = (1, 4, 'text', 'test', False, 4.44)
print(my_tuple[4])
print(my_tuple.count(4))

# %%
my_set = {1, 666, 'test', 2.44, False, None}
# print(my_set[2])
my_set.add('kotya')
print(my_set)
# Out:
# {False, 1, 2.44, None, 'test', 'kotya', 666}

# %%
list1 = list(set([1, 4, 5, 7, 2, 5]))
# list1 = set(list1)
print(list1)
# Out:
# [1, 2, 4, 5, 7]

# %%
my_dict = {'one': 'value', 'two': 'value2'}
print(my_dict['one'])
print(len(my_dict))
my_dict['one'] = 'my_value'
my_dict['three'] = 'value3'
my_dict['four'] = False
my_dict['five'] = [1, 5, 8]
my_dict['six'] = {1, 7, 8}
my_dict[666] = 'teeeest'
my_dict[2.28] = 'seeees'
my_dict[(1, 2, 6)] = 'mmmmm'

print(my_dict)

print(my_dict.keys())
print(my_dict.values())
print(my_dict.items())
# Out:
# value
# 2
# {'one': 'my_value', 'two': 'value2', 'three': 'value3', 'four': False, 'five': [1, 5, 8], 'six': {8, 1, 7}, 666: 'teeeest', 2.28: 'seeees', (1, 2, 6): 'mmmmm'}
# dict_keys(['one', 'two', 'three', 'four', 'five', 'six', 666, 2.28, (1, 2, 6)])
# dict_values(['my_value', 'value2', 'value3', False, [1, 5, 8], {8, 1, 7}, 'teeeest', 'seeees', 'mmmmm'])
# dict_items([('one', 'my_value'), ('two', 'value2'), ('three', 'value3'), ('four', False), ('five', [1, 5, 8]), ('six', {8, 1, 7}), (666, 'teeeest'), (2.28, 'seeees'), ((1, 2, 6), 'mmmmm')])
